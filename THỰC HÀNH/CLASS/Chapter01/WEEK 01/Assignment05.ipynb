# %% [markdown]
# # Tìm hiểu JSON/XML

# %% [markdown]
# # Áp dụng import và export dữ liệu JSON/XML

# %% [markdown]
# # Biến đổi từ dạng table (tức 2D) sang JSON.
# Tham khảo: https://docs.python.org/3/library/json.html
