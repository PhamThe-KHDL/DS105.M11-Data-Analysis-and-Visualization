# %% [markdown]
# # Dùng **scrapy** để thu thập dữ liệu web (cấp độ đơn giản)
#
# Hướng dẫn: https://doc.scrapy.org/en/latest/intro/tutorial.html

# %%
# !pip install scrapy
# Out:
# ...
#      |████████████████████████████████| 254 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 40.5 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 39.7 MB/s
# ...
#      |████████████████████████████████| 65 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 251 kB 69.8 MB/s
# ...
#      |████████████████████████████████| 47 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 41.3 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.0 MB/s
# ...
#   Created wheel for protego: filename=Protego-0.1.16-py3-none-any.whl size=7782 sha256=abd7ca61537b5a7702a885b16e059f1a97711a1bc4f4361f8f1d32dc0ad0931a
#   Stored in directory: /root/.cache/pip/wheels/ca/44/01/3592ccfbcfaee4ab297c4097e6e9dbe1c7697e3531a39877ab
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11515 sha256=b9d69b394ef8c5e6c9e83c339eab71873895a90df45ab97d3958aa713a45c76b
# ...

# %%
import scrapy

# %% [markdown]
# ## Thực hiện trên môi trương Anaconda
